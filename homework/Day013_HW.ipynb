# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

# %%
import pandas as pd

info_all = []
for d in soup.find_all(class_="title"):
    try:
        url = 'https://www.ptt.cc/' + d.find('a')['href']
        # print(url)
        soup_2 = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        info = []
        for dd in soup_2.find_all(class_='article-meta-value'):
            info.append(dd.text)
        info_all.append(info)
    except:
        continue
df = pd.DataFrame(info_all, columns=['作者', '看板', '標題', '時間'])
df
# Out:
#                             作者    看板                                      標題  \
# 0              SAC430 (sac430)   NBA            [新聞] NBA戰術板 居然MADE IN TAIWAN
# 1                humbler (獸人H)   NBA            [討論] 人們將追逐 Bogdan Bogdanovic
# 2       KevinLove (Kevin Love)   NBA                 [討論] 哪隻奪冠球隊適合Kevin Love
# 3              Angel0724 (ND5)   NBA                [新聞] 保羅遭火箭隊交易 安東尼：曾叫他要小心
# 4         MrSatan (老大!!!!!!!!)   NBA              Re: [討論] AD現在有比巔峰KG強嗎？(數據)
# 5                 iammatrix ()   NBA                  Re: [討論] AD現在有比巔峰KG強嗎？
# 6            thnlkj0665 (灰色地帶)   NBA          [情報] Josh Jackson 違反隊規  遭到禁賽一場
# 7               YESGOTO (潮州渝民)   NBA                      [討論] KERR師父究竟有沒有料？
# 8                         None  None                                    None
# 9                   Vedan (味丹)   NBA                      [公告] 樂透取消及未來不再開啟樂透
# 10  qazwsx879345 (Rajon Rondo)   NBA                           [公告] 版主上任相關事項
# 11              JerroLi (銀色小刀)   NBA  [情報] SEASON Schedule 賽程 December 19–20
# 12         dragon803 (好想去露營啊~)   NBA          [公告]是否禁止basketball top 5文章投票開始
#
#                           時間
# 0   Tue Dec 10 19:44:46 2019
# 1   Tue Dec 10 19:54:19 2019
# 2   Tue Dec 10 20:48:54 2019
# 3   Tue Dec 10 21:05:54 2019
# 4   Tue Dec 10 21:37:39 2019
# 5   Tue Dec 10 21:51:16 2019
# 6   Tue Dec 10 22:22:25 2019
# 7   Tue Dec 10 22:56:29 2019
# 8                       None
# 9   Mon Jun 24 15:08:02 2019
# 10  Fri Oct 25 10:44:03 2019
# 11  Fri Nov 29 00:46:01 2019
# 12  Sun Dec  8 23:55:00 2019

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/stock/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

# %%
import pandas as pd

info_all = []
for d in soup.find_all(class_="title"):
    try:
        url = 'https://www.ptt.cc/' + d.find('a')['href']
        # print(url)
        soup_2 = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        info = []
        for dd in soup_2.find_all(class_='article-meta-value'):
            info.append(dd.text)
        info.append(url)
        info_all.append(info)
    except:
        continue
df = pd.DataFrame(info_all, columns=['作者', '看板', '標題', '時間', 'URL'])
df
# Out:
#                                                    作者     看板  \
# 0                                      hedgehogs (刺蝟)  Stock
# 1                                Reewalker (報告饅頭班長不夠)  Stock
# 2                                   hito21 (come3哈密瓜)  Stock
# 3                                          Su22 (裝配匠)  Stock
# 4                                  sakula0616 (沙庫拉大大)  Stock
# 5                                        DALUGI (大陸雞)  Stock
# 6                                      kylenboy (走走吧)  Stock
# 7                             DaGG30cm (Always Lucky)  Stock
# 8                                         redh (redh)  Stock
# 9                                    asustor (tor...)  Stock
# 10                                   STAV72 (刁民黨黨務主委)  Stock
# 11                                      IanLi (IanLi)  Stock
# 12  https://www.ptt.cc//bbs/Stock/M.1541252211.A.8...   None
# 13                                    vendan5566 (阿文)  Stock
#
#                               標題                        時間  \
# 0      [新聞] 工研院：台灣發展再生能源勢在必行 應具5  Tue Dec 10 20:22:24 2019
# 1     [新聞] 2019年房市驚奇！商用不動產、土地交易量  Tue Dec 10 21:03:02 2019
# 2               [標的] 美國道瓊(*UDZ9)  Tue Dec 10 21:20:58 2019
# 3        [新聞] 銀行股再現閃崩 A股上市銀行普遍低迷  Tue Dec 10 21:32:04 2019
# 4                Re: [標的] 台北股市 空  Tue Dec 10 21:51:35 2019
# 5   Re: [新聞] 反擊美國！中國下令公家機關3年內換掉外  Tue Dec 10 21:57:13 2019
# 6           [請益] 有券商可以定期不定額買股票嗎?  Tue Dec 10 22:00:20 2019
# 7        [請益] 專職今年報酬多少及格？鄉民都賺多少呢  Tue Dec 10 22:34:35 2019
# 8      Re: [請益] 「存股」跟「定存股」的意思有差嗎  Tue Dec 10 22:39:57 2019
# 9               [請益] 推薦的兒童帳戶+證券戶  Tue Dec 10 22:45:45 2019
# 10      [新聞] 上市櫃大陸、海外投資收益 連三季雙衰退  Tue Dec 10 23:35:27 2019
# 11                 [公告] 精華區導覽Q&A  Sun Jan 25 23:18:20 2015
# 12                          None                      None
# 13          [閒聊] 2019/12/10 盤後閒聊  Tue Dec 10 14:00:05 2019
#
#                                                   URL
# 0   https://www.ptt.cc//bbs/Stock/M.1575980548.A.5...
# 1   https://www.ptt.cc//bbs/Stock/M.1575982983.A.4...
# 2   https://www.ptt.cc//bbs/Stock/M.1575984060.A.6...
# 3   https://www.ptt.cc//bbs/Stock/M.1575984726.A.5...
# 4   https://www.ptt.cc//bbs/Stock/M.1575985897.A.E...
# 5   https://www.ptt.cc//bbs/Stock/M.1575986235.A.9...
# 6   https://www.ptt.cc//bbs/Stock/M.1575986422.A.0...
# 7   https://www.ptt.cc//bbs/Stock/M.1575988477.A.4...
# 8   https://www.ptt.cc//bbs/Stock/M.1575988799.A.B...
# 9   https://www.ptt.cc//bbs/Stock/M.1575989147.A.F...
# 10  https://www.ptt.cc//bbs/Stock/M.1575992129.A.2...
# 11  https://www.ptt.cc//bbs/Stock/M.1422199105.A.8...
# 12                                               None
# 13  https://www.ptt.cc//bbs/Stock/M.1575957607.A.9...
