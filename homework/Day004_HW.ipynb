# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11116398159","type":"PullRequestEvent","actor":{"id":52787017,"login":"itpp-bot","display_login":"itpp-bot","gravatar_id":"","url":"https://api.github.com/users/itpp-bot","avatar_url":"https://avatars.githubusercontent.com/u/52787017?"},"repo":{"id":19877687,"name":"it-projects-llc/misc-addons","url":"https://api.github.com/repos/it-projects-llc/misc-addons"},"payload":{"action":"closed","number":881,"pull_request":{"url":"https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881","id":354500821,"node_id":"MDExOlB1bGxSZXF1ZXN0MzU0NTAwODIx","html_url":"https://github.com/it-projects-llc/misc-addons/pull/881","diff_url":"https://github.com/it-projects-llc/misc-addons/pull/881.diff","patch_url":"https://github.com/it-projects-llc/misc-addons/pull/881.patch","issue_url":"https://api.github.com/repos/it-projects-llc/misc-addons/issues/881","number":881,"state":"closed","locked":false,"title":"12.0 -> 13.0 (auto)","user":{"login":"fedoranvar","id":52028706,"node_id":"MDQ6VXNlcjUyMDI4NzA2","avatar_url":"https://avatars0.githubusercontent.com/u/52028706?v=4","gravatar_id":"","url":"https://api.github.com/users/fedoranvar","html_url":"https://github.com/fedoranvar","followers_url":"https://api.github.com/users/fedoranvar/followers","following_url":"https://api.github.com/users/fedoranvar/following{/other_user}","gists_url":"https://api.github.com/users/fedoranvar/gists{/gist_id}","starred_url":"https://api.github.com/users/fedoranvar/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/fedoranvar/subscriptions","organizations_url":"https://api.github.com/users/fedoranvar/orgs","repos_url":"https://api.github.com/users/fedoranvar/repos","events_url":"https://api.github.com/users/fedoranvar/events{/privacy}","received_events_url":"https://api.github.com/users/fedoranvar/received_events","type":"User","site_admin":false},"body":"This is auto merge from fedoranvar:13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3 to 13.0","created_at":"2019-12-18T09:00:09Z","updated_at":"2019-12-18T12:55:43Z","closed_at":"2019-12-18T12:55:42Z","merged_at":"2019-12-18T12:55:42Z","merge_commit_sha":"faa20d3189ab6c39f0c8525483f0e73c6841cd65","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/commits","review_comments_url":"https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/comments","review_comment_url":"https://api.github.com/repos/it-projects-llc/misc-addons/pulls/comments{/number}","comments_url":"https://api.github.com/repos/it-projects-llc/misc-addons/issues/881/comments","statuses_url":"https://api.github.com/repos/it-projects-llc/misc-addons/statuses/df03740beaacb63c9d88090740babc92d2fa581f","head":{"label":"fedoranvar:13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3","ref":"13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3","sha":"df03740beaacb63c9d88090740babc92d2fa581f","user":{"login":"fedoranvar","id":52028706,"node_id":"MDQ6VXNlcjUyMDI4NzA2","avatar_url":"https://avatars0.githubusercontent.com/u/52028706?v=4","gravatar_id":"","url":"https://api.github.com/users/fedoranvar","html_url":"https://github.com/fedoranvar","followers_url":"https://api.github.com/users/fedoranvar/followers","following_url":"https://api.github.com/users/fedoranvar/following{/other_user}","gists_url":"https://api.github.com/users/fedoranvar/gists{/gist_id}","starred_url":"https://api.github.com/users/fedoranvar/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/fedoranvar/subscriptions","organizations_url":"https://api.github.com/users/fedoranvar/orgs","repos_url":"https://api.github.com/users/fedoranvar/repos","events_url":"https://api.github.com/users/fedoranvar/events{/privacy}","received_events_url":"https://api.github.com/users/fedoranvar/received_events","type":"User","site_admin":false},"repo":{"id":200789380,"node_id":"MDEwOlJlcG9zaXRvc ...

# %%
type(r.text)
# Out:
# str

# %%
import json

# json.loads: 將json格式資料轉換為字典
json.loads(r.text)
# Out:
# [{'id': '11116398159',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 52787017,
#    'login': 'itpp-bot',
#    'display_login': 'itpp-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itpp-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52787017?'},
#   'repo': {'id': 19877687,
#    'name': 'it-projects-llc/misc-addons',
#    'url': 'https://api.github.com/repos/it-projects-llc/misc-addons'},
#   'payload': {'action': 'closed',
#    'number': 881,
#    'pull_request': {'url': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881',
#     'id': 354500821,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU0NTAwODIx',
#     'html_url': 'https://github.com/it-projects-llc/misc-addons/pull/881',
#     'diff_url': 'https://github.com/it-projects-llc/misc-addons/pull/881.diff',
#     'patch_url': 'https://github.com/it-projects-llc/misc-addons/pull/881.patch',
#     'issue_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/881',
#     'number': 881,
#     'state': 'closed',
#     'locked': False,
#     'title': '12.0 -> 13.0 (auto)',
#     'user': {'login': 'fedoranvar',
#      'id': 52028706,
#      'node_id': 'MDQ6VXNlcjUyMDI4NzA2',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/52028706?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fedoranvar',
#      'html_url': 'https://github.com/fedoranvar',
#      'followers_url': 'https://api.github.com/users/fedoranvar/followers',
#      'following_url': 'https://api.github.com/users/fedoranvar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fedoranvar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fedoranvar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fedoranvar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fedoranvar/orgs',
#      'repos_url': 'https://api.github.com/users/fedoranvar/repos',
#      'events_url': 'https://api.github.com/users/fedoranvar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fedoranvar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This is auto merge from fedoranvar:13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3 to 13.0',
#     'created_at': '2019-12-18T09:00:09Z',
#     'updated_at': '2019-12-18T12:55:43Z',
#     'closed_at': '2019-12-18T12:55:42Z',
#     'merged_at': '2019-12-18T12:55:42Z',
#     'merge_commit_sha': 'faa20d3189ab6c39f0c8525483f0e73c6841cd65',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/commits',
#     'review_comments_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/comments',
#     'review_comment_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/881/comments',
#     'statuses_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/statuses/df03740beaacb63c9d88090740babc92d2fa581f',
#     'head': {'label': 'fedoranvar:13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3',
#      'ref': '13.0-automerge-3439d42d3785ca83da38ca734238961d633a04b3',
#      'sha': 'df03740beaacb63c9d88090740babc92d2fa581f',
#      'user': {'login': 'fedoranvar',
#       'id': 52028706,
#       'node_id': 'MDQ6VXNlcjUyMDI4NzA2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/52028706?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fedoranvar',
#       'html_url': 'https://github.com/fedoranvar',
#       'followers_url': 'https://api.github.com/users/fedoranvar/followers',
#       'following_url': 'https://api.github.com/users/fedoranvar/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fedoranvar/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fedoranvar/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fedoranvar/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fedoranvar/orgs',
#       'repos_url': 'https://api.github.com/users/fedoranvar/repos',
#       'events_url': 'https://api.github.com/users/fedoranvar/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fedoranvar/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 200789380,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDA3ODkzODA=',
#       'name': 'misc-addons',
#       'full_name': 'fedoranvar/misc-addons',
#       'private': False,
#       'owner': {'login': 'fedoranvar',
#        'id': 52028706,
#        'node_id': 'MDQ6VXNlcjUyMDI4NzA2',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/52028706?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/fedoranvar',
#        'html_url': 'https://github.com/fedoranvar',
#        'followers_url': 'https://api.github.com/users/fedoranvar/followers',
#        'following_url': 'https://api.github.com/users/fedoranvar/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/fedoranvar/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/fedoranvar/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/fedoranvar/subscriptions',
#        'organizations_url': 'https://api.github.com/users/fedoranvar/orgs',
#        'repos_url': 'https://api.github.com/users/fedoranvar/repos',
#        'events_url': 'https://api.github.com/users/fedoranvar/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/fedoranvar/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/fedoranvar/misc-addons',
#       'description': 'Odoo addons',
#       'fork': True,
#       'url': 'https://api.github.com/repos/fedoranvar/misc-addons',
#       'forks_url': 'https://api.github.com/repos/fedoranvar/misc-addons/forks',
#       'keys_url': 'https://api.github.com/repos/fedoranvar/misc-addons/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/fedoranvar/misc-addons/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/fedoranvar/misc-addons/teams',
#       'hooks_url': 'https://api.github.com/repos/fedoranvar/misc-addons/hooks',
#       'issue_events_url': 'https://api.github.com/repos/fedoranvar/misc-addons/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/fedoranvar/misc-addons/events',
#       'assignees_url': 'https://api.github.com/repos/fedoranvar/misc-addons/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/fedoranvar/misc-addons/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/fedoranvar/misc-addons/tags',
#       'blobs_url': 'https://api.github.com/repos/fedoranvar/misc-addons/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/fedoranvar/misc-addons/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/fedoranvar/misc-addons/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/fedoranvar/misc-addons/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/fedoranvar/misc-addons/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/fedoranvar/misc-addons/languages',
#       'stargazers_url': 'https://api.github.com/repos/fedoranvar/misc-addons/stargazers',
#       'contributors_url': 'https://api.github.com/repos/fedoranvar/misc-addons/contributors',
#       'subscribers_url': 'https://api.github.com/repos/fedoranvar/misc-addons/subscribers',
#       'subscription_url': 'https://api.github.com/repos/fedoranvar/misc-addons/subscription',
#       'commits_url': 'https://api.github.com/repos/fedoranvar/misc-addons/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/fedoranvar/misc-addons/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/fedoranvar/misc-addons/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/fedoranvar/misc-addons/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/fedoranvar/misc-addons/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/fedoranvar/misc-addons/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/fedoranvar/misc-addons/merges',
#       'archive_url': 'https://api.github.com/repos/fedoranvar/misc-addons/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/fedoranvar/misc-addons/downloads',
#       'issues_url': 'https://api.github.com/repos/fedoranvar/misc-addons/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/fedoranvar/misc-addons/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/fedoranvar/misc-addons/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/fedoranvar/misc-addons/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/fedoranvar/misc-addons/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/fedoranvar/misc-addons/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/fedoranvar/misc-addons/deployments',
#       'created_at': '2019-08-06T06:23:49Z',
#       'updated_at': '2019-08-30T17:44:51Z',
#       'pushed_at': '2019-12-18T12:18:26Z',
#       'git_url': 'git://github.com/fedoranvar/misc-addons.git',
#       'ssh_url': 'git@github.com:fedoranvar/misc-addons.git',
#       'clone_url': 'https://github.com/fedoranvar/misc-addons.git',
#       'svn_url': 'https://github.com/fedoranvar/misc-addons',
#       'homepage': 'https://www.it-projects.info/',
#       'size': 27940,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'lgpl-3.0',
#        'name': 'GNU Lesser General Public License v3.0',
#        'spdx_id': 'LGPL-3.0',
#        'url': 'https://api.github.com/licenses/lgpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTEy'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': '12.0'}},
#     'base': {'label': 'it-projects-llc:13.0',
#      'ref': '13.0',
#      'sha': '8bb42db3323da4718c1aceb66df5b8d55a28c9fe',
#      'user': {'login': 'it-projects-llc',
#       'id': 17959306,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3OTU5MzA2',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/17959306?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/it-projects-llc',
#       'html_url': 'https://github.com/it-projects-llc',
#       'followers_url': 'https://api.github.com/users/it-projects-llc/followers',
#       'following_url': 'https://api.github.com/users/it-projects-llc/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/it-projects-llc/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/it-projects-llc/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/it-projects-llc/subscriptions',
#       'organizations_url': 'https://api.github.com/users/it-projects-llc/orgs',
#       'repos_url': 'https://api.github.com/users/it-projects-llc/repos',
#       'events_url': 'https://api.github.com/users/it-projects-llc/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/it-projects-llc/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 19877687,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTg3NzY4Nw==',
#       'name': 'misc-addons',
#       'full_name': 'it-projects-llc/misc-addons',
#       'private': False,
#       'owner': {'login': 'it-projects-llc',
#        'id': 17959306,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3OTU5MzA2',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/17959306?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/it-projects-llc',
#        'html_url': 'https://github.com/it-projects-llc',
#        'followers_url': 'https://api.github.com/users/it-projects-llc/followers',
#        'following_url': 'https://api.github.com/users/it-projects-llc/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/it-projects-llc/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/it-projects-llc/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/it-projects-llc/subscriptions',
#        'organizations_url': 'https://api.github.com/users/it-projects-llc/orgs',
#        'repos_url': 'https://api.github.com/users/it-projects-llc/repos',
#        'events_url': 'https://api.github.com/users/it-projects-llc/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/it-projects-llc/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/it-projects-llc/misc-addons',
#       'description': 'Odoo addons',
#       'fork': False,
#       'url': 'https://api.github.com/repos/it-projects-llc/misc-addons',
#       'forks_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/forks',
#       'keys_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/teams',
#       'hooks_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/hooks',
#       'issue_events_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/events',
#       'assignees_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/tags',
#       'blobs_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/languages',
#       'stargazers_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/stargazers',
#       'contributors_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/contributors',
#       'subscribers_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/subscribers',
#       'subscription_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/subscription',
#       'commits_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/merges',
#       'archive_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/downloads',
#       'issues_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/it-projects-llc/misc-addons/deployments',
#       'created_at': '2014-05-17T03:41:54Z',
#       'updated_at': '2019-12-09T09:54:47Z',
#       'pushed_at': '2019-12-18T12:55:42Z',
#       'git_url': 'git://github.com/it-projects-llc/misc-addons.git',
#       'ssh_url': 'git@github.com:it-projects-llc/misc-addons.git',
#       'clone_url': 'https://github.com/it-projects-llc/misc-addons.git',
#       'svn_url': 'https://github.com/it-projects-llc/misc-addons',
#       'homepage': 'https://www.it-projects.info/',
#       'size': 27982,
#       'stargazers_count': 228,
#       'watchers_count': 228,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 521,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 38,
#       'license': {'key': 'lgpl-3.0',
#        'name': 'GNU Lesser General Public License v3.0',
#        'spdx_id': 'LGPL-3.0',
#        'url': 'https://api.github.com/licenses/lgpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTEy'},
#       'forks': 521,
#       'open_issues': 38,
#       'watchers': 228,
#       'default_branch': '13.0'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881'},
#      'html': {'href': 'https://github.com/it-projects-llc/misc-addons/pull/881'},
#      'issue': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/881'},
#      'comments': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/issues/881/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/pulls/881/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/it-projects-llc/misc-addons/statuses/df03740beaacb63c9d88090740babc92d2fa581f'}},
#     'author_association': 'MEMBER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'itpp-bot',
#      'id': 52787017,
#      'node_id': 'MDQ6VXNlcjUyNzg3MDE3',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/52787017?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/itpp-bot',
#      'html_url': 'https://github.com/itpp-bot',
#      'followers_url': 'https://api.github.com/users/itpp-bot/followers',
#      'following_url': 'https://api.github.com/users/itpp-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/itpp-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/itpp-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/itpp-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/itpp-bot/orgs',
#      'repos_url': 'https://api.github.com/users/itpp-bot/repos',
#      'events_url': 'https://api.github.com/users/itpp-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/itpp-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 6,
#     'additions': 51,
#     'deletions': 29,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z',
#   'org': {'id': 17959306,
#    'login': 'it-projects-llc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/it-projects-llc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17959306?'}},
#  {'id': '11116398177',
#   'type': 'PushEvent',
#   'actor': {'id': 47018051,
#    'login': 'OpenMIS-backup',
#    'display_login': 'OpenMIS-backup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OpenMIS-backup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47018051?'},
#   'repo': {'id': 183115745,
#    'name': 'OpenMIS-backup/WalBackup_N-DataDirectoryCreateDateTime-2018-12-16-19_40_32',
#    'url': 'https://api.github.com/repos/OpenMIS-backup/WalBackup_N-DataDirectoryCreateDateTime-2018-12-16-19_40_32'},
#   'payload': {'push_id': 4411936881,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3692cf34af879120dd665d785bb7da9330fca6b3',
#    'before': '306e7db21964925f5a9b8771fbb49902b6b74b8f',
#    'commits': [{'sha': '3692cf34af879120dd665d785bb7da9330fca6b3',
#      'author': {'email': '47018051+OpenMIS-backup@users.noreply.github.com',
#       'name': 'OpenMIS-backup'},
#      'message': '',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OpenMIS-backup/WalBackup_N-DataDirectoryCreateDateTime-2018-12-16-19_40_32/commits/3692cf34af879120dd665d785bb7da9330fca6b3'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398156',
#   'type': 'PushEvent',
#   'actor': {'id': 58211463,
#    'login': 'chaimabelgaied',
#    'display_login': 'chaimabelgaied',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaimabelgaied',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58211463?'},
#   'repo': {'id': 224151122,
#    'name': 'chaimabelgaied/IA_TP',
#    'url': 'https://api.github.com/repos/chaimabelgaied/IA_TP'},
#   'payload': {'push_id': 4411936867,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7252f887c1d5039bacaa544cd5516cd89b495882',
#    'before': '527ec4e5d3c02a9ef9eaf7e9f2ab5342aa125c69',
#    'commits': [{'sha': '7252f887c1d5039bacaa544cd5516cd89b495882',
#      'author': {'email': '58211463+chaimabelgaied@users.noreply.github.com',
#       'name': 'chaimabelgaied'},
#      'message': 'Update test.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chaimabelgaied/IA_TP/commits/7252f887c1d5039bacaa544cd5516cd89b495882'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398141',
#   'type': 'PushEvent',
#   'actor': {'id': 3866882,
#    'login': 'krystofl',
#    'display_login': 'krystofl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krystofl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3866882?'},
#   'repo': {'id': 228834291,
#    'name': 'krystofl/klog-assets',
#    'url': 'https://api.github.com/repos/krystofl/klog-assets'},
#   'payload': {'push_id': 4411936860,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ca8442350d8db2a89c25bbb62870da69d399661f',
#    'before': '0d0e02082f18697c5fbcd431e0ac3fa1b9cba375',
#    'commits': [{'sha': 'ca8442350d8db2a89c25bbb62870da69d399661f',
#      'author': {'email': 'krystof@litomisky.com', 'name': 'Krystof Litomisky'},
#      'message': 'Added sidebar image in static subfolder',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/krystofl/klog-assets/commits/ca8442350d8db2a89c25bbb62870da69d399661f'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398157',
#   'type': 'PushEvent',
#   'actor': {'id': 18753195,
#    'login': 'jiji4000',
#    'display_login': 'jiji4000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jiji4000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18753195?'},
#   'repo': {'id': 224573553,
#    'name': 'jiji4000/AIZU_ONLINE_JUDGE_PYTHON',
#    'url': 'https://api.github.com/repos/jiji4000/AIZU_ONLINE_JUDGE_PYTHON'},
#   'payload': {'push_id': 4411936871,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '231100a7405c20abaa86bf32ecbac2aab4ea544f',
#    'before': '460195b43c538d3335c978008b628c2001a19251',
#    'commits': [{'sha': '231100a7405c20abaa86bf32ecbac2aab4ea544f',
#      'author': {'email': 'jiji4000alpha@gmail.com', 'name': 'jiji4000'},
#      'message': 'add 0006.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jiji4000/AIZU_ONLINE_JUDGE_PYTHON/commits/231100a7405c20abaa86bf32ecbac2aab4ea544f'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398144',
#   'type': 'DeleteEvent',
#   'actor': {'id': 682440,
#    'login': 'pepov',
#    'display_login': 'pepov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pepov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/682440?'},
#   'repo': {'id': 138716355,
#    'name': 'banzaicloud/logging-operator',
#    'url': 'https://api.github.com/repos/banzaicloud/logging-operator'},
#   'payload': {'ref': 'bug/docs7', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z',
#   'org': {'id': 32848483,
#    'login': 'banzaicloud',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/banzaicloud',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32848483?'}},
#  {'id': '11116398147',
#   'type': 'PushEvent',
#   'actor': {'id': 55203354,
#    'login': 'eneritz5',
#    'display_login': 'eneritz5',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eneritz5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55203354?'},
#   'repo': {'id': 225339134,
#    'name': 'AmaiaAretxalde/proyecto-urbegi-cliente',
#    'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente'},
#   'payload': {'push_id': 4411936870,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fed2df2516850467b209bd33a6f27cfbd3ace38f',
#    'before': 'ca10b95ba612097137bda81c187d3a3d38ac973c',
#    'commits': [{'sha': 'e2e3b4ccc230541034a35d06e10d041e58ddf528',
#      'author': {'email': 'enebu.eb@gmail.com', 'name': 'eneritz5'},
#      'message': '18dic',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/commits/e2e3b4ccc230541034a35d06e10d041e58ddf528'},
#     {'sha': 'fed2df2516850467b209bd33a6f27cfbd3ace38f',
#      'author': {'email': '55203354+eneritz5@users.noreply.github.com',
#       'name': 'eneritz5'},
#      'message': 'Merge pull request #32 from AmaiaAretxalde/front-end-eneritz\n\n18dic',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/commits/fed2df2516850467b209bd33a6f27cfbd3ace38f'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398140',
#   'type': 'DeleteEvent',
#   'actor': {'id': 26876514,
#    'login': 'tbpg',
#    'display_login': 'tbpg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tbpg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26876514?'},
#   'repo': {'id': 43332504,
#    'name': 'GoogleCloudPlatform/golang-samples',
#    'url': 'https://api.github.com/repos/GoogleCloudPlatform/golang-samples'},
#   'payload': {'ref': 'video', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z',
#   'org': {'id': 2810941,
#    'login': 'GoogleCloudPlatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GoogleCloudPlatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2810941?'}},
#  {'id': '11116398111',
#   'type': 'PushEvent',
#   'actor': {'id': 56959837,
#    'login': 'anyagagliano',
#    'display_login': 'anyagagliano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anyagagliano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56959837?'},
#   'repo': {'id': 228820030,
#    'name': 'Raffelsax/skepp',
#    'url': 'https://api.github.com/repos/Raffelsax/skepp'},
#   'payload': {'push_id': 4411936848,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6ab34741699b073b05c8b815ebd89b16b64e26b7',
#    'before': 'c27d635281db304f39cf84c22ed5c8102d263a07',
#    'commits': [{'sha': '6ab34741699b073b05c8b815ebd89b16b64e26b7',
#      'author': {'email': 'anyagagliano87@gmail.com', 'name': 'Anna'},
#      'message': 'Ändring',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Raffelsax/skepp/commits/6ab34741699b073b05c8b815ebd89b16b64e26b7'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398104',
#   'type': 'PushEvent',
#   'actor': {'id': 26600937,
#    'login': 'usrdev',
#    'display_login': 'usrdev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/usrdev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26600937?'},
#   'repo': {'id': 201959900,
#    'name': 'packethost/docs',
#    'url': 'https://api.github.com/repos/packethost/docs'},
#   'payload': {'push_id': 4411936841,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b5b79803d6fa8c8b98e79a0997c0ffe1b69a58fe',
#    'before': '78a29fb21602f21c3153bb9053482d9f3e1e716b',
#    'commits': [{'sha': '8601ffd562b9df6f52b0ca8970602d1db4a27fc6',
#      'author': {'email': 'mo@usr.dev', 'name': 'mo'},
#      'message': 'updating titles',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/packethost/docs/commits/8601ffd562b9df6f52b0ca8970602d1db4a27fc6'},
#     {'sha': 'b5b79803d6fa8c8b98e79a0997c0ffe1b69a58fe',
#      'author': {'email': 'mo@usr.dev', 'name': 'mo'},
#      'message': 'Merge pull request #277 from packethost/issue-262-2\n\nupdating titles',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/packethost/docs/commits/b5b79803d6fa8c8b98e79a0997c0ffe1b69a58fe'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z',
#   'org': {'id': 7982021,
#    'login': 'packethost',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/packethost',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7982021?'}},
#  {'id': '11116398100',
#   'type': 'PushEvent',
#   'actor': {'id': 30404851,
#    'login': 'ryotokuro',
#    'display_login': 'ryotokuro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryotokuro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30404851?'},
#   'repo': {'id': 227756731,
#    'name': 'ryotokuro/adventofcode',
#    'url': 'https://api.github.com/repos/ryotokuro/adventofcode'},
#   'payload': {'push_id': 4411936844,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0d8ec92d3a1aea30d833910f0ec0d3df27a3fb4d',
#    'before': '0b7b8ab78542d2284566aab0cf3d2179a4bcfcc3',
#    'commits': [{'sha': '0d8ec92d3a1aea30d833910f0ec0d3df27a3fb4d',
#      'author': {'email': 'ryotokuro@gmail.com', 'name': 'ryotokuro'},
#      'message': 'added new day file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ryotokuro/adventofcode/commits/0d8ec92d3a1aea30d833910f0ec0d3df27a3fb4d'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398081',
#   'type': 'ForkEvent',
#   'actor': {'id': 1506917,
#    'login': 'gdelmondo',
#    'display_login': 'gdelmondo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gdelmondo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1506917?'},
#   'repo': {'id': 214037979,
#    'name': 'suoto/hdl_checker_vscode',
#    'url': 'https://api.github.com/repos/suoto/hdl_checker_vscode'},
#   'payload': {'forkee': {'id': 228840179,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjg4NDAxNzk=',
#     'name': 'hdl_checker_vscode',
#     'full_name': 'gdelmondo/hdl_checker_vscode',
#     'private': False,
#     'owner': {'login': 'gdelmondo',
#      'id': 1506917,
#      'node_id': 'MDQ6VXNlcjE1MDY5MTc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1506917?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gdelmondo',
#      'html_url': 'https://github.com/gdelmondo',
#      'followers_url': 'https://api.github.com/users/gdelmondo/followers',
#      'following_url': 'https://api.github.com/users/gdelmondo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gdelmondo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gdelmondo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gdelmondo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gdelmondo/orgs',
#      'repos_url': 'https://api.github.com/users/gdelmondo/repos',
#      'events_url': 'https://api.github.com/users/gdelmondo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gdelmondo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/gdelmondo/hdl_checker_vscode',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode',
#     'forks_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/forks',
#     'keys_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/teams',
#     'hooks_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/hooks',
#     'issue_events_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/events',
#     'assignees_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/tags',
#     'blobs_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/languages',
#     'stargazers_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/stargazers',
#     'contributors_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/contributors',
#     'subscribers_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/subscribers',
#     'subscription_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/subscription',
#     'commits_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/merges',
#     'archive_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/downloads',
#     'issues_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/gdelmondo/hdl_checker_vscode/deployments',
#     'created_at': '2019-12-18T12:55:42Z',
#     'updated_at': '2019-12-18T10:47:56Z',
#     'pushed_at': '2019-12-18T10:47:53Z',
#     'git_url': 'git://github.com/gdelmondo/hdl_checker_vscode.git',
#     'ssh_url': 'git@github.com:gdelmondo/hdl_checker_vscode.git',
#     'clone_url': 'https://github.com/gdelmondo/hdl_checker_vscode.git',
#     'svn_url': 'https://github.com/gdelmondo/hdl_checker_vscode',
#     'homepage': None,
#     'size': 425,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-18T12:55:43Z'},
#  {'id': '11116398082',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 55203354,
#    'login': 'eneritz5',
#    'display_login': 'eneritz5',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eneritz5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55203354?'},
#   'repo': {'id': 225339134,
#    'name': 'AmaiaAretxalde/proyecto-urbegi-cliente',
#    'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente'},
#   'payload': {'action': 'closed',
#    'number': 32,
#    'pull_request': {'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/pulls/32',
#     'id': 354598760,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU0NTk4NzYw',
#     'html_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente/pull/32',
#     'diff_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente/pull/32.diff',
#     'patch_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente/pull/32.patch',
#     'issue_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/issues/32',
#     'number': 32,
#     'state': 'closed',
#     'locked': False,
#     'title': '18dic',
#     'user': {'login': 'eneritz5',
#      'id': 55203354,
#      'node_id': 'MDQ6VXNlcjU1MjAzMzU0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/55203354?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eneritz5',
#      'html_url': 'https://github.com/eneritz5',
#      'followers_url': 'https://api.github.com/users/eneritz5/followers',
#      'following_url': 'https://api.github.com/users/eneritz5/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eneritz5/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eneritz5/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eneritz5/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eneritz5/orgs',
#      'repos_url': 'https://api.github.com/users/eneritz5/repos',
#      'events_url': 'https://api.github.com/users/eneritz5/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eneritz5/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-18T12:55:27Z',
#     'updated_at': '2019-12-18T12:55:42Z',
#     'closed_at': '2019-12-18T12:55:42Z',
#     'merged_at': '2019-12-18T12:55:42Z',
#     'merge_commit_sha': 'fed2df2516850467b209bd33a6f27cfbd3ace38f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/pulls/32/commits',
#     'review_comments_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/pulls/32/comments',
#     'review_comment_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/issues/32/comments',
#     'statuses_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/statuses/e2e3b4ccc230541034a35d06e10d041e58ddf528',
#     'head': {'label': 'AmaiaAretxalde:front-end-eneritz',
#      'ref': 'front-end-eneritz',
#      'sha': 'e2e3b4ccc230541034a35d06e10d041e58ddf528',
#      'user': {'login': 'AmaiaAretxalde',
#       'id': 55448190,
#       'node_id': 'MDQ6VXNlcjU1NDQ4MTkw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/55448190?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AmaiaAretxalde',
#       'html_url': 'https://github.com/AmaiaAretxalde',
#       'followers_url': 'https://api.github.com/users/AmaiaAretxalde/followers',
#       'following_url': 'https://api.github.com/users/AmaiaAretxalde/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AmaiaAretxalde/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AmaiaAretxalde/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AmaiaAretxalde/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AmaiaAretxalde/orgs',
#       'repos_url': 'https://api.github.com/users/AmaiaAretxalde/repos',
#       'events_url': 'https://api.github.com/users/AmaiaAretxalde/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AmaiaAretxalde/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 225339134,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjUzMzkxMzQ=',
#       'name': 'proyecto-urbegi-cliente',
#       'full_name': 'AmaiaAretxalde/proyecto-urbegi-cliente',
#       'private': False,
#       'owner': {'login': 'AmaiaAretxalde',
#        'id': 55448190,
#        'node_id': 'MDQ6VXNlcjU1NDQ4MTkw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/55448190?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AmaiaAretxalde',
#        'html_url': 'https://github.com/AmaiaAretxalde',
#        'followers_url': 'https://api.github.com/users/AmaiaAretxalde/followers',
#        'following_url': 'https://api.github.com/users/AmaiaAretxalde/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AmaiaAretxalde/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AmaiaAretxalde/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AmaiaAretxalde/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AmaiaAretxalde/orgs',
#        'repos_url': 'https://api.github.com/users/AmaiaAretxalde/repos',
#        'events_url': 'https://api.github.com/users/AmaiaAretxalde/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AmaiaAretxalde/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente',
#       'forks_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/forks',
#       'keys_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/teams',
#       'hooks_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/events',
#       'assignees_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/tags',
#       'blobs_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/languages',
#       'stargazers_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/subscription',
#       'commits_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/merges',
#       'archive_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/downloads',
#       'issues_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AmaiaAretxalde/proyecto-urbegi-cliente/deployments',
#       'created_at': '2019-12-02T09:44:17Z',
#       'updated_at': '2019-12-18T12:39:02Z',
#       'pushed_at': '2019-12-18T12:55:42Z',
#       'git_url': 'git://github.com/AmaiaAretxalde/proyecto-urbegi-cliente.git',
#       'ssh_url': 'git@github.com:AmaiaAretxalde/proyecto-urbegi-cliente.git',
#       'clone_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente.git',
#       'svn_url': 'https://github.com/AmaiaAretxalde/proyecto-urbegi-cliente',
#       'homepage': None,
#       'size': 3496,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
# ...
#      'author': {'email': 'eklove.walia@payu.in', 'name': 'Eklove Singh Walia'},
#      'message': 'adding readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ekluv/payu-checkout-examples/commits/9a2ae93723af708289b6e2159b5d2d3e726f714c'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z'},
#  {'id': '11116398043',
#   'type': 'PushEvent',
#   'actor': {'id': 561644,
#    'login': 'songwentong',
#    'display_login': 'songwentong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/songwentong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/561644?'},
#   'repo': {'id': 60939735,
#    'name': 'songwentong/WTKit',
#    'url': 'https://api.github.com/repos/songwentong/WTKit'},
#   'payload': {'push_id': 4411936810,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '498834ce911b37c667637ab988dc0cb283bf79ce',
#    'before': '8fc4b861e4a3cd6cc0402c516e1dc9bd75240532',
#    'commits': [{'sha': '498834ce911b37c667637ab988dc0cb283bf79ce',
#      'author': {'email': 'songwentong@hinterstellar.com',
#       'name': 'songwentong'},
#      'message': 'os iOS',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/songwentong/WTKit/commits/498834ce911b37c667637ab988dc0cb283bf79ce'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z'},
#  {'id': '11116398041',
#   'type': 'PushEvent',
#   'actor': {'id': 57952984,
#    'login': 'IDungeon',
#    'display_login': 'IDungeon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IDungeon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57952984?'},
#   'repo': {'id': 222716819,
#    'name': 'tisabe/CP2_QPP',
#    'url': 'https://api.github.com/repos/tisabe/CP2_QPP'},
#   'payload': {'push_id': 4411936796,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'aad0069c1c468c5c551803df45141d7f5a2aa5b2',
#    'before': '8690a9b3db224654ac180a21e3cad94285b2aebd',
#    'commits': [{'sha': 'aad0069c1c468c5c551803df45141d7f5a2aa5b2',
#      'author': {'email': '57952984+IDungeon@users.noreply.github.com',
#       'name': 'IDungeon'},
#      'message': 'Update strang_splitting.c',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tisabe/CP2_QPP/commits/aad0069c1c468c5c551803df45141d7f5a2aa5b2'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z'},
#  {'id': '11116398017',
#   'type': 'IssuesEvent',
#   'actor': {'id': 54824174,
#    'login': 'Vimax12345',
#    'display_login': 'Vimax12345',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vimax12345',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54824174?'},
#   'repo': {'id': 160498353,
#    'name': 'readthedocs/test-builds',
#    'url': 'https://api.github.com/repos/readthedocs/test-builds'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/readthedocs/test-builds/issues/438',
#     'repository_url': 'https://api.github.com/repos/readthedocs/test-builds',
#     'labels_url': 'https://api.github.com/repos/readthedocs/test-builds/issues/438/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/readthedocs/test-builds/issues/438/comments',
#     'events_url': 'https://api.github.com/repos/readthedocs/test-builds/issues/438/events',
#     'html_url': 'https://github.com/readthedocs/test-builds/issues/438',
#     'id': 539663904,
#     'node_id': 'MDU6SXNzdWU1Mzk2NjM5MDQ=',
#     'number': 438,
#     'title': 'Apotik Jual Cytotec Di Dharmasraya 082214655588 Obat Penggugur Janen',
#     'user': {'login': 'Vimax12345',
#      'id': 54824174,
#      'node_id': 'MDQ6VXNlcjU0ODI0MTc0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/54824174?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Vimax12345',
#      'html_url': 'https://github.com/Vimax12345',
#      'followers_url': 'https://api.github.com/users/Vimax12345/followers',
#      'following_url': 'https://api.github.com/users/Vimax12345/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Vimax12345/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Vimax12345/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Vimax12345/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Vimax12345/orgs',
#      'repos_url': 'https://api.github.com/users/Vimax12345/repos',
#      'events_url': 'https://api.github.com/users/Vimax12345/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Vimax12345/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-18T12:55:42Z',
#     'updated_at': '2019-12-18T12:55:42Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Apotik Jual Cytotec Obat Penggugur Kandungan Di Dharmasraya, Cytotec Asli Aman Tuntas Tanpa Efek Samping,\r\nApotik Cytotec Obat Telat Bulan Tuntas, Jual Obat Aborsi Cytotec, Agen Obat Aborsi Asli, Obat Penggugur Janen Cytotec Aman Dan Tuntas, Cytotec Obat Aborsi Tuntas, Obat Aborsi Asli, Obat Aborsi Cytotec Asli, Jual Obat Aborsi, Obat Cytotec, Penjual Obat Aborsi, Tempat jual Obat Aborsi, Alamat Penjual Obat Aborsi, Penjual Cytotec, Jual Cytotec, Jual Obat Cytotec, Penjual Cytotec, Apotik Yang jual Cytotec, Tempat Apotik Obat Cytotec, Cytotec Penggugur Kandungan, Jual Obat Penggugur Kandungan Cytotec, Obat Cytotec Menggugur Kandungan Asli, Obat penggugur janin Cytotec, Obat peluntur Janin Cytotec, Obat Penggugur Kandungan Cytotec.\r\n\r\nAlamat Apotik Jual Obat Aborsi Penggugur Kandungan Cytotec Asli terpercaya Di sini kami menjual berbagai macam obat aborsi cytotec misoprostol pfizer asli obat penggugur kandungan cytotec asli Apotik Penjual Obat Aborsi belakangan ini banyak sekali yang mengaku bidan yang bisa menggugurkan kandungan ( aborsi ) atau dokter, saya harap anda hati2 untuk bidan kuret, karena alat kuret hanya dokter yang mempunyai alat tersebut, kalau si bidan atau si dokter tersebut menawarkan obat aborsi cytotec, atau obat aborsi lainnya, pastikan dulu website atau blog nya mempunya bukti bahwa dia benar2 memiliki obat untuk aborsi janin dan kandungan tersebut, jadi kalau sebuah blog tidak punya bukti memiliki obat jangan coba2 membeli dari web atau blog tersebut, obat aja tidak punya lalu apa yang mau dikirim ?\r\nBagi wanita yang ingin menggugurkan kandungannya karena terbelit masalah yang sangat serius, misalnya, ada penyakit yang mengancam keselamatan sang ibu yang mengandungnya, masalah ekonomi, hasil pemerkosaan, maupun hasil hubungan gelap dan ternyata pasangannya tidak mau bertanggung jawab, oleh sebab itu jika anda tersandung masalah tersebut dan jika anda ingin melakukan tindakan aborsi dengan menggunkan obat, anda tidak salah tempat, karena di sini menyediakan Obat Aborsi yang bisa anda beli disini.\r\nBagaimana cara mendapatkan obat di Apotik Penjual Obat Aborsi ? kami akan memberikan kemudahan untuk anda tanpa harus mencari atau membawa resep dokter, Obat cytotec untuk Aborsi Merupakan tahap bagaimana seseorang dalam melakukan tindakan menggugurkan sebuah kehamilan atau kandungan dengan metode obat yang di dapat di KAMI dengan cara dan langkah-langkah yang diberikan oleh pihak kami yang ahli dalam proses pengguguran sebuah kandungan yang berusia 1 4 bulan lamanya obat aborsi yang tingkat keberhasilannya mencapai 98% karena obat ini sudah sangat banyak digunakan bagi wanita yang tidak ingin meneruskan kandungan dikarena kan sesuatu hal tertentu, obat ini mempunyai nama Mifepristone ( juga dikenal dengan nama pil abortus, RU 486, Mifegyn, Mifeprex ), dan Misoprostol ( juga dikenal dengan nama Cytotec, Arthrotec, Oxaprost, Cyprostol, Mibetec, Prostokos or Misotrol ). sebelum anda melakukan yang lebih bersifat riskan lebih baiknya anda berfikir untuk lebih baiknya sebelum menggunakan jasa kami ini.\r\nBACA JUGA PENJELASAN DETAIL Obat Aborsi Cytotec\r\nHati Hati Penipuan. Teliti Sebelum Membeli !\r\nBerikut ini kami informasikan beberapa tips yang dapat membantu anda untuk membedakan penjual yang asli dan yang palsu atau penipuan agar anda tidak salah tempat membeli :\r\nTidak Bisa Cash On Delivery (C.O.D) atau ketemuan pihak pembeli dan penjual.Penjualan obat ini merupakan suatu yang ilegal atau dilarang di Indonesia, jadi jika ada website yang menawarkan penjualan dengan sistem C.O.D atau ketemuan, mereka tidak akan bertahan lama karena pasti akan segera tertangkap oleh pihak kepolisian.\r\nObat Aborsi Ijin Depkes. Obat ini tidak akan ada DEPKES atau BPOM karena di Indonesia aborsi tidak di izinkan atau diperbolehkan, jadi obat aborsi hanya di akui FDA USA (Food and Drug Administration). Jika ada penjual yang mengatakan sudah ada ijin depkes ataupun bpom itu jelas PENIPUAN !\r\nTips Menghi ...
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z',
#   'org': {'id': 366329,
#    'login': 'readthedocs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/readthedocs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/366329?'}},
#  {'id': '11116398016',
#   'type': 'PushEvent',
#   'actor': {'id': 57661612,
#    'login': 'am43-sanger',
#    'display_login': 'am43-sanger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/am43-sanger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57661612?'},
#   'repo': {'id': 197594876,
#    'name': 'wtsi-hgi/hgi-cloud',
#    'url': 'https://api.github.com/repos/wtsi-hgi/hgi-cloud'},
#   'payload': {'push_id': 4411936790,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/hdfs',
#    'head': 'aac875c10c15ea83c3eab3d31389cd96798c2e61',
#    'before': 'd555bd42b27d7f6337c96c6433a2a5a86c721278',
#    'commits': [{'sha': 'aac875c10c15ea83c3eab3d31389cd96798c2e61',
#      'author': {'email': 'am43@sanger.ac.uk', 'name': 'Andrew McIsaac'},
#      'message': 'Set JAVA_HOME environment variable for namenode formatting',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wtsi-hgi/hgi-cloud/commits/aac875c10c15ea83c3eab3d31389cd96798c2e61'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z',
#   'org': {'id': 2567468,
#    'login': 'wtsi-hgi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wtsi-hgi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2567468?'}},
#  {'id': '11116398011',
#   'type': 'PushEvent',
#   'actor': {'id': 46982041,
#    'login': 'lyy1005664097',
#    'display_login': 'lyy1005664097',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lyy1005664097',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46982041?'},
#   'repo': {'id': 227946734,
#    'name': 'lyy1005664097/lsp',
#    'url': 'https://api.github.com/repos/lyy1005664097/lsp'},
#   'payload': {'push_id': 4411936793,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '24e53f24313326760f2551de20b4c14b48bffb1b',
#    'before': '6989f48fd67a952ef7aebff8bb53cf3206683559',
#    'commits': [{'sha': '24e53f24313326760f2551de20b4c14b48bffb1b',
#      'author': {'email': '1005664097@qq.com', 'name': 'lyy1005664097'},
#      'message': '陈关奇、侯璐鑫 1.4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lyy1005664097/lsp/commits/24e53f24313326760f2551de20b4c14b48bffb1b'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z'},
#  {'id': '11116398009',
#   'type': 'PushEvent',
#   'actor': {'id': 35459775,
#    'login': 'appearhere-otto',
#    'display_login': 'appearhere-otto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/appearhere-otto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35459775?'},
#   'repo': {'id': 65029029,
#    'name': 'appearhere/bloom',
#    'url': 'https://api.github.com/repos/appearhere/bloom'},
#   'payload': {'push_id': 4411936786,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '8b8ec24055bfe86ddf86bf4298cca1497a133da4',
#    'before': '109114f94b9735504b3c308fbf8ec797020c3882',
#    'commits': [{'sha': '8b8ec24055bfe86ddf86bf4298cca1497a133da4',
#      'author': {'email': 'hello@ghbot.com', 'name': 'GH Pages Bot'},
#      'message': 'Deploy Storybook to GitHub Pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/appearhere/bloom/commits/8b8ec24055bfe86ddf86bf4298cca1497a133da4'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z',
#   'org': {'id': 6638466,
#    'login': 'appearhere',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/appearhere',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6638466?'}},
#  {'id': '11116398013',
#   'type': 'PushEvent',
#   'actor': {'id': 37038626,
#    'login': 'geos4s',
#    'display_login': 'geos4s',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/geos4s',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37038626?'},
#   'repo': {'id': 159298221,
#    'name': 'geos4s/18w856162',
#    'url': 'https://api.github.com/repos/geos4s/18w856162'},
#   'payload': {'push_id': 4411936779,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'af0976067d366185eccb32abe7c82b59e578da8f',
#    'before': '70f84d473840caccb20c792143fe3d9a89eb47f0',
#    'commits': [{'sha': 'af0976067d366185eccb32abe7c82b59e578da8f',
#      'author': {'email': '37038626+geos4s@users.noreply.github.com',
#       'name': 'geos4s'},
#      'message': 'Add sgroup07/metar_eddt.csv',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/geos4s/18w856162/commits/af0976067d366185eccb32abe7c82b59e578da8f'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z'},
#  {'id': '11116398005',
#   'type': 'PushEvent',
#   'actor': {'id': 12244231,
#    'login': 'itjun',
#    'display_login': 'itjun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itjun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12244231?'},
#   'repo': {'id': 218519501,
#    'name': 'cn-cerc/summer-framework',
#    'url': 'https://api.github.com/repos/cn-cerc/summer-framework'},
#   'payload': {'push_id': 4411936787,
#    'size': 5,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'ecbba550afadcfa81c200715106bd995c09eeaa6',
#    'before': '6923271cd3e9b1b774be43e236910e34c056bbd7',
#    'commits': [{'sha': '343b38f9e0af74d1b4150fbc4dcb4a90a76f5e1b',
#      'author': {'email': '18476661381@163.com', 'name': '颜家智'},
#      'message': '获取用户登录信息新增通过远程服务获取用户信息',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cn-cerc/summer-framework/commits/343b38f9e0af74d1b4150fbc4dcb4a90a76f5e1b'},
#     {'sha': 'ddbb7b3999eed7bf9b72c8d88861a9b85e2e0750',
#      'author': {'email': '18476661381@163.com', 'name': '颜家智'},
#      'message': '重构代码',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cn-cerc/summer-framework/commits/ddbb7b3999eed7bf9b72c8d88861a9b85e2e0750'},
#     {'sha': 'b18b350e008d587b4c51b52a02003b28c13a4e03',
#      'author': {'email': '18476661381@163.com', 'name': '颜家智'},
#      'message': '重构代码',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cn-cerc/summer-framework/commits/b18b350e008d587b4c51b52a02003b28c13a4e03'},
#     {'sha': '5e2cb462e051cb16550cf6fa7cc50981a420a344',
#      'author': {'email': '18476661381@163.com', 'name': '颜家智'},
#      'message': '修改服务名',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cn-cerc/summer-framework/commits/5e2cb462e051cb16550cf6fa7cc50981a420a344'},
#     {'sha': 'ecbba550afadcfa81c200715106bd995c09eeaa6',
#      'author': {'email': 'l1091462907@gmail.com', 'name': '黄荣君'},
#      'message': 'Merge pull request #51 from cn-cerc/yjz-updateAppSessionRestore\n\n获取用户登录信息新增通过远程服务获取用户信息',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cn-cerc/summer-framework/commits/ecbba550afadcfa81c200715106bd995c09eeaa6'}]},
#   'public': True,
#   'created_at': '2019-12-18T12:55:42Z',
#   'org': {'id': 20215553,
#    'login': 'cn-cerc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cn-cerc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20215553?'}}]

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008ad0aac31001185ed0c","text":"The frequency of a domestic cat\'s purr is the same at which muscles and bones repair themselves.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"5955792c7b77520020799431","text":"Cats \\"knead\\" because of seperation from their mothers","type":"cat","user":{"_id":"595579027b77520020799430","name":{"first":"Is It Still Memes That","last":"Make You Sweat?"}},"upvotes":5,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes": ...

# %%
import json

json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
